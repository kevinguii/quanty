# %%
import requests
api_key = 'F9Q1FY1ZYNGHUWDJ'
symbol = 'IBM'

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={symbol}&interval=5min&apikey={api_key}'
url_test = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo'
r = requests.get(url)
data = r.json()

r_test = requests.get(url_test)
data_test = r_test.json()

# %%
import pandas as pd

# Assume `data` is your full JSON dictionary (as shown above)
# You only want the "Time Series (5min)" part
time_series = data_test["Time Series (5min)"]

# Convert to DataFrame
df = pd.DataFrame.from_dict(time_series, orient='index')

# Clean up column names
df.columns = ['open', 'high', 'low', 'close', 'volume']

# Convert index to datetime
df.index = pd.to_datetime(df.index)

# Ensure numeric values
df = df.apply(pd.to_numeric)

# Optional: reset index and rename it to 'datetime'
df = df.reset_index().rename(columns={'index': 'datetime'})

df
# Out:
#               datetime    open    high       low     close  volume
# 0  2025-09-03 19:55:00  244.02  244.02  244.0200  244.0200       2
# 1  2025-09-03 19:50:00  244.13  244.17  244.1300  244.1700      18
# 2  2025-09-03 19:45:00  244.08  244.17  243.8000  244.1600      25
# 3  2025-09-03 19:40:00  244.08  244.17  244.0800  244.0800      46
# 4  2025-09-03 19:35:00  244.07  244.08  244.0200  244.0800      22
# ..                 ...     ...     ...       ...       ...     ...
# 95 2025-09-03 11:50:00  242.02  242.25  242.0100  242.1200   14780
# 96 2025-09-03 11:45:00  241.93  242.04  241.9000  242.0000   21568
# 97 2025-09-03 11:40:00  242.15  242.20  241.9469  241.9469   20280
# 98 2025-09-03 11:35:00  242.13  242.37  242.0201  242.1100   23310
# 99 2025-09-03 11:30:00  241.95  242.16  241.8900  242.1100   21546
#
# [100 rows x 6 columns]
